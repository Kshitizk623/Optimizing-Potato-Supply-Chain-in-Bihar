# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("C:/Users/kshit/Downloads/scm project/cold storage bihar.xlsx")

# %%
df.head()
# Out:
#     Sl No                                   Name & Address  Capacity in MT  \
# 0  ARARIA                                              NaN             NaN
# 1       1  BISCOMAUN1 Cold Storage, Agrl. Yard, Forbesganj          4000.0
# 2       2           Ganga Cold Storage (P) Ltd., Bathunaha          5850.0
# 3       3      Sima Cold Storage & Ice Factory, Forbesganj          1700.0
# 4     NaN                                     Araria Total         11550.0
#
#    Sector Commodity Remarks
# 0     NaN       NaN     NaN
# 1  Co-op.    Potato     NaN
# 2    Pvt.    Potato     NaN
# 3    Pvt.    Potato     NaN
# 4     NaN       NaN     NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 329 entries, 0 to 328
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sl No           267 non-null    object
#  1   Name & Address  268 non-null    object
#  2   Capacity in MT  268 non-null    float64
#  3   Sector          237 non-null    object
#  4   Commodity       237 non-null    object
#  5   Remarks         16 non-null     object
# dtypes: float64(1), object(5)
# memory usage: 15.5+ KB

# %%
df = df[~df['Name & Address'].str.contains('Total', case=False, na=False)]

# Display the cleaned DataFrame
print(df)
# Out:
#       Sl No                                     Name & Address  \
# 0    ARARIA                                                NaN
# 1         1    BISCOMAUN1 Cold Storage, Agrl. Yard, Forbesganj
# 2         2             Ganga Cold Storage (P) Ltd., Bathunaha
# 3         3        Sima Cold Storage & Ice Factory, Forbesganj
# 5       NaN                                                NaN
# ..      ...                                                ...
# 322       5         Kisan Cold Storage, Vill. Kaurihat, Raxaul
# 323       6  Nanasati Ice & Cold Storage (P) Ltd.,Nanasati,...
# 324       7    Narkatiyaganj Ice & Cold Storage, Narkatiyaganj
# 325       8       Rajgharia Cold Storage & Ice Factory, Betiah
# 327     NaN                                                NaN
#
#      Capacity in MT  Sector     Commodity Remarks
# 0               NaN     NaN           NaN     NaN
# 1            4000.0  Co-op.        Potato     NaN
# 2            5850.0    Pvt.        Potato     NaN
# ...

# %%
df.head(30)
# Out:
#          Sl No                                     Name & Address  \
# 0       ARARIA                                                NaN
# 1            1    BISCOMAUN1 Cold Storage, Agrl. Yard, Forbesganj
# 2            2             Ganga Cold Storage (P) Ltd., Bathunaha
# 3            3        Sima Cold Storage & Ice Factory, Forbesganj
# 5          NaN                                                NaN
# 6   AURANGABAD                                                NaN
# 7            1  Shankar Cold Storage And Ice Factory, Ramchand...
# 9          NaN                                                NaN
# 10   BEGUSARAI                                                NaN
# 11           1    Anupam Cold Storage (P) Ltd., Phulwari, Barauni
# 12           2              Barauni Co-op. Sitagarh Ltd., Barauni
# 13           3    Begusarai Cold Storage & Ice Factory, Begusarai
# 14           4          Himganga Cold Storage (P) Ltd., Begusarai
# ...

# %%
df = df.dropna(how='all')

# %%
df.head(20)
# Out:
#          Sl No                                     Name & Address  \
# 0       ARARIA                                                NaN
# 1            1    BISCOMAUN1 Cold Storage, Agrl. Yard, Forbesganj
# 2            2             Ganga Cold Storage (P) Ltd., Bathunaha
# 3            3        Sima Cold Storage & Ice Factory, Forbesganj
# 6   AURANGABAD                                                NaN
# 7            1  Shankar Cold Storage And Ice Factory, Ramchand...
# 10   BEGUSARAI                                                NaN
# 11           1    Anupam Cold Storage (P) Ltd., Phulwari, Barauni
# 12           2              Barauni Co-op. Sitagarh Ltd., Barauni
# 13           3    Begusarai Cold Storage & Ice Factory, Begusarai
# 14           4          Himganga Cold Storage (P) Ltd., Begusarai
# 15           5  Kesav Sheet Bhandar (P) Ltd., Ramjanpur, Begus...
# 16           6               Laxmi Cold Storage, Viwan, Begasarai
# ...

# %%
df.tail(5)
# Out:
#     Sl No                                     Name & Address  Capacity in MT  \
# 321     4  Dumuria Joint Farming Co-op. Society Ltd., Dum...          2500.0
# 322     5         Kisan Cold Storage, Vill. Kaurihat, Raxaul          5300.0
# 323     6  Nanasati Ice & Cold Storage (P) Ltd.,Nanasati,...          8000.0
# 324     7    Narkatiyaganj Ice & Cold Storage, Narkatiyaganj          2312.0
# 325     8       Rajgharia Cold Storage & Ice Factory, Betiah          3600.0
#
#      Sector     Commodity Remarks
# 321  Co-op.        Potato     NaN
# 322    Pvt.  Multipurpose     NaN
# 323    Pvt.        Potato     NaN
# 324    Pvt.        Potato     NaN
# 325    Pvt.        Potato     NaN

# %%
nan_rows = df[df['Sl No'].isna()]

# Print the result
print(nan_rows)
# Out:
# Empty DataFrame
# Columns: [Sl No, Name & Address, Capacity in MT, Sector, Commodity, Remarks]
# Index: []

# %%
df.to_excel('C:/Users/kshit/Downloads/scm project/df.xlsx', index=False)

print("excel file saved successfully.")
# Out:
# excel file saved successfully.

# %%
bihar_cold_storage = pd.read_excel("C:/Users/kshit/Downloads/scm project/df_cleaned.xlsx")

# %%
bihar_cold_storage.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237 entries, 0 to 236
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sl No           237 non-null    object
#  1   Name & Address  237 non-null    object
#  2   Capacity in MT  237 non-null    int64
#  3   Sector          237 non-null    object
#  4   Commodity       237 non-null    object
#  5   Remarks         16 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 11.2+ KB

# %%
bihar_cold_storage.rename(columns={'Sl No': 'District', 'Capacity in MT': 'Capacity'}, inplace=True)

# Display the updated DataFrame
print(bihar_cold_storage.head())
# Out:
#      District                                     Name & Address  Capacity  \
# 0      ARARIA    BISCOMAUN1 Cold Storage, Agrl. Yard, Forbesganj      4000
# 1      ARARIA             Ganga Cold Storage (P) Ltd., Bathunaha      5850
# 2      ARARIA        Sima Cold Storage & Ice Factory, Forbesganj      1700
# 3  AURANGABAD  Shankar Cold Storage And Ice Factory, Ramchand...      1400
# 4   BEGUSARAI    Anupam Cold Storage (P) Ltd., Phulwari, Barauni      5000
#
#    Sector     Commodity Remarks
# 0  Co-op.        Potato     NaN
# 1    Pvt.        Potato     NaN
# 2    Pvt.        Potato     NaN
# 3    Pvt.        Potato     NaN
# 4    Pvt.  Multipurpose     NaN

# %%
bihar_cold_storage.head(15)
# Out:
#       District                                     Name & Address  Capacity  \
# 0       ARARIA    BISCOMAUN1 Cold Storage, Agrl. Yard, Forbesganj      4000
# 1       ARARIA             Ganga Cold Storage (P) Ltd., Bathunaha      5850
# 2       ARARIA        Sima Cold Storage & Ice Factory, Forbesganj      1700
# 3   AURANGABAD  Shankar Cold Storage And Ice Factory, Ramchand...      1400
# 4    BEGUSARAI    Anupam Cold Storage (P) Ltd., Phulwari, Barauni      5000
# 5    BEGUSARAI              Barauni Co-op. Sitagarh Ltd., Barauni      4300
# 6    BEGUSARAI    Begusarai Cold Storage & Ice Factory, Begusarai      1300
# 7    BEGUSARAI          Himganga Cold Storage (P) Ltd., Begusarai      6000
# 8    BEGUSARAI  Kesav Sheet Bhandar (P) Ltd., Ramjanpur, Begus...      6000
# 9    BEGUSARAI               Laxmi Cold Storage, Viwan, Begasarai      5500
# 10   BEGUSARAI                    Mithila Cold Storage, Begusarai      7500
# ...

# %%
bihar_cold_storage.isnull().sum()
# Out:
# District            0
# Name & Address      0
# Capacity            0
# Sector              0
# Commodity           0
# Remarks           221
# dtype: int64

# %%
biharpotatodata = pd.read_excel("C:/Users/kshit/Downloads/scm project/horizontal_crop_vertical_year_report (6)(in).xlsx")

# %%
biharpotatodata['District'] = biharpotatodata['District'].str.upper()

# %%
biharpotatodata['District'].value_counts()
# Out:
# District
# 1. ARARIA                 1
# 29. ROHTAS                1
# 22. MUZAFFARPUR           1
# 23. NALANDA               1
# 24. NAWADA                1
# 25. PASHCHIM CHAMPARAN    1
# 26. PATNA                 1
# 27. PURBI CHAMPARAN       1
# 28. PURNIA                1
# 30. SAHARSA               1
# 2. ARWAL                  1
# 31. SAMASTIPUR            1
# 32. SARAN                 1
# 33. SHEIKHPURA            1
# 34. SHEOHAR               1
# 35. SITAMARHI             1
# 36. SIWAN                 1
# 37. SUPAUL                1
# 21. MUNGER                1
# 20. MADHUBANI             1
# 19. MADHEPURA             1
# 18. LAKHISARAI            1
# 3. AURANGABAD             1
# 4. BANKA                  1
# 5. BEGUSARAI              1
# 6. BHAGALPUR              1
# 7. BHOJPUR                1
# 8. BUXAR                  1
# 9. DARBHANGA              1
# 10. GAYA                  1
# 11. GOPALGANJ             1
# 12. JAMUI                 1
# ...

# %%
biharpotatodata['District'] = biharpotatodata['District'].str.replace(r'^\d+\.', '', regex=True).str.strip()

# %%
set1 = set(biharpotatodata['District'].unique())

# %%
set2 = set(bihar_cold_storage['District'].unique())

# %%
set1
# Out:
# {'ARARIA',
#  'ARWAL',
#  'AURANGABAD',
#  'BANKA',
#  'BEGUSARAI',
#  'BHAGALPUR',
#  'BHOJPUR',
#  'BUXAR',
#  'DARBHANGA',
#  'GAYA',
#  'GOPALGANJ',
#  'JAMUI',
#  'JEHANABAD',
#  'KAIMUR (BHABUA)',
#  'KATIHAR',
#  'KHAGARIA',
#  'KISHANGANJ',
#  'LAKHISARAI',
#  'MADHEPURA',
#  'MADHUBANI',
#  'MUNGER',
#  'MUZAFFARPUR',
#  'NALANDA',
#  'NAWADA',
#  'PASHCHIM CHAMPARAN',
#  'PATNA',
#  'PURBI CHAMPARAN',
#  'PURNIA',
#  'ROHTAS',
#  'SAHARSA',
#  'SAMASTIPUR',
#  'SARAN',
#  'SHEIKHPURA',
#  'SHEOHAR',
#  'SITAMARHI',
#  'SIWAN',
#  'SUPAUL',
#  'VAISHALI'}

# %%
set2
# Out:
# {'ARARIA',
#  'AURANGABAD',
#  'BEGUSARAI',
#  'BHABUA',
#  'BHAGALPUR',
#  'BHOJPUR',
#  'BUXER',
#  'DARBHANGA',
#  'EASTCHAMPARAN',
#  'GAYA',
#  'GOPALGANJ',
#  'JAHANABAD',
#  'KATIHAR',
#  'KHAGARIA',
#  'LAKHISARAI',
#  'MADHUBANI',
#  'MUJAFFARPUR',
#  'NALANDA',
#  'NAWADAH',
#  'PATNA',
#  'PURNIA',
#  'ROHTAS',
#  'SAHARSA',
#  'SAMASTIPUR',
#  'SARAN',
#  'SEIKHPURA',
#  'SITAMARHI',
#  'SIWAN',
#  'VAISHALI',
#  'WESTCHAMPARAN'}

# %%
bihar_cold_storage['District'] = bihar_cold_storage['District'].replace({'WESTCHAMPARAN': 'PASHCHIM CHAMPARAN', 'EASTCHAMPARAN': 'PURBI CHAMPARAN','BHABUA': 'KAIMUR (BHABUA)','NAWADAH':"NAWADA","BUXER":"BUXAR","JAHANABAD":"JEHANABAD","MUJAFFARPUR":"MUZAFFARPUR",'SEIKHPURA':'SHEIKHPURA'})

# %%
len(set1)
# Out:
# 38

# %%
len(set2)
# Out:
# 30

# %%
set1
# Out:
# {'ARARIA',
#  'ARWAL',
#  'AURANGABAD',
#  'BANKA',
#  'BEGUSARAI',
#  'BHAGALPUR',
#  'BHOJPUR',
#  'BUXAR',
#  'DARBHANGA',
#  'GAYA',
#  'GOPALGANJ',
#  'JAMUI',
#  'JEHANABAD',
#  'KAIMUR (BHABUA)',
#  'KATIHAR',
#  'KHAGARIA',
#  'KISHANGANJ',
#  'LAKHISARAI',
#  'MADHEPURA',
#  'MADHUBANI',
#  'MUNGER',
#  'MUZAFFARPUR',
#  'NALANDA',
#  'NAWADA',
#  'PASHCHIM CHAMPARAN',
#  'PATNA',
#  'PURBI CHAMPARAN',
#  'PURNIA',
#  'ROHTAS',
#  'SAHARSA',
#  'SAMASTIPUR',
#  'SARAN',
#  'SHEIKHPURA',
#  'SHEOHAR',
#  'SITAMARHI',
#  'SIWAN',
#  'SUPAUL',
#  'VAISHALI'}

# %%
set2 = set(bihar_cold_storage['District'].unique())

# %%
set2
# Out:
# {'ARARIA',
#  'AURANGABAD',
#  'BEGUSARAI',
#  'BHAGALPUR',
#  'BHOJPUR',
#  'BUXAR',
#  'DARBHANGA',
#  'GAYA',
#  'GOPALGANJ',
#  'JEHANABAD',
#  'KAIMUR (BHABUA)',
#  'KATIHAR',
#  'KHAGARIA',
#  'LAKHISARAI',
#  'MADHUBANI',
#  'MUZAFFARPUR',
#  'NALANDA',
#  'NAWADA',
#  'PASHCHIM CHAMPARAN',
#  'PATNA',
#  'PURBI CHAMPARAN',
#  'PURNIA',
#  'ROHTAS',
#  'SAHARSA',
#  'SAMASTIPUR',
#  'SARAN',
#  'SHEIKHPURA',
#  'SITAMARHI',
#  'SIWAN',
#  'VAISHALI'}

# %%
len(set1.difference(set2))
# Out:
# 8

# %%
set1.difference(set2)
# Out:
# {'ARWAL',
#  'BANKA',
#  'JAMUI',
#  'KISHANGANJ',
#  'MADHEPURA',
#  'MUNGER',
#  'SHEOHAR',
#  'SUPAUL'}

# %%
bihar_cold_storage['District'] = bihar_cold_storage['District'].replace({'JEHANANBAD':'JEHANABAD'})

# %%
set1.difference(set2)
# Out:
# {'ARWAL',
#  'BANKA',
#  'JAMUI',
#  'KISHANGANJ',
#  'MADHEPURA',
#  'MUNGER',
#  'SHEOHAR',
#  'SUPAUL'}

# %%
set2 = set(bihar_cold_storage['District'].unique())

# %%
len(set1.difference(set2))
# Out:
# 8

# %%
district_list = list(set1)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
cold_storage_counts = bihar_cold_storage.groupby('District').size().reset_index(name='cold_storage_count')
df = 
# Display results in tabular form
print("Number of Cold Storages in Each District:\n", cold_storage_counts)

# Plotting the results
plt.figure(figsize=(10, 6))
plt.bar(cold_storage_counts['District'], cold_storage_counts['cold_storage_count'], color='skyblue')
plt.xlabel('District')
plt.ylabel('Number of Cold Storages')
plt.title('Number of Cold Storages per District')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# Number of Cold Storages in Each District:
#                District  cold_storage_count
# 0               ARARIA                   3
# 1           AURANGABAD                   1
# 2            BEGUSARAI                  11
# 3            BHAGALPUR                   6
# 4              BHOJPUR                   3
# 5                BUXAR                   4
# 6            DARBHANGA                   1
# 7                 GAYA                  17
# 8            GOPALGANJ                  11
# 9            JEHANABAD                   2
# 10     KAIMUR (BHABUA)                   1
# 11             KATIHAR                   3
# 12            KHAGARIA                   1
# 13          LAKHISARAI                   1
# 14           MADHUBANI                   2
# 15         MUZAFFARPUR                  13
# 16             NALANDA                  32
# 17              NAWADA                   4
# 18  PASHCHIM CHAMPARAN                   8
# 19               PATNA                  25
# ...

# %%
bihar_cold_storage.groupby('Sector')['Capacity'].mean().plot(kind='bar', figsize=(10, 6), title="Average Capacity by Sector")
# Out:
# <Axes: title={'center': 'Average Capacity by Sector'}, xlabel='Sector'>

# %%
bihar_cold_storage.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237 entries, 0 to 236
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   District        237 non-null    object
#  1   Name & Address  237 non-null    object
#  2   Capacity        237 non-null    int64
#  3   Sector          237 non-null    object
#  4   Commodity       237 non-null    object
#  5   Remarks         16 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 11.2+ KB

# %%
import requests
import pandas as pd
from geopy.distance import geodesic

# Your OpenCage API Key
API_KEY = "cdd95e2537de4679966f4a36f505b9f5"
base_url = "https://api.opencagedata.com/geocode/v1/json"

# List of districts
districts = district_list
# List to hold coordinates
coordinates = []

# Fetch coordinates for each district
for district in districts:
    params = {
        "q": f"{district}, India",
        "key": API_KEY,
        "limit": 1
    }
    response = requests.get(base_url, params=params)
    if response.status_code == 200:
        data = response.json()
        if data['results']:
            location = data['results'][0]['geometry']
            coordinates.append({
                'District': district,
                'Latitude': location['lat'],
                'Longitude': location['lng']
            })
        else:
            coordinates.append({
                'District': district,
                'Latitude': None,
                'Longitude': None
            })
    else:
        coordinates.append({
            'District': district,
            'Latitude': None,
            'Longitude': None
        })

# Create DataFrame for coordinates
df_coordinates = pd.DataFrame(coordinates)

# Calculate distances between all pairs of districts
distance_data = []

# Nested loops to calculate distance between each pair
for i in range(len(df_coordinates)):
    for j in range(len(df_coordinates)):
        if i != j:  # Avoid calculating distance to itself
            district_a = df_coordinates.iloc[i]
            district_b = df_coordinates.iloc[j]
            
            # Check if both districts have valid coordinates
            if district_a['Latitude'] is not None and district_a['Longitude'] is not None and \
               district_b['Latitude'] is not None and district_b['Longitude'] is not None:
                
                coords_a = (district_a['Latitude'], district_a['Longitude'])
                coords_b = (district_b['Latitude'], district_b['Longitude'])
                
                # Calculate distance
                distance = geodesic(coords_a, coords_b).kilometers
                
                # Append to the list
                distance_data.append({
                    'From': district_a['District'],
                    'To': district_b['District'],
                    'Distance_km': distance
                })

# Create a DataFrame for distances
df_distances = pd.DataFrame(distance_data)

# Print the distances DataFrame
print("\nDistance DataFrame:")
print(df_distances)
# Out:
# Distance DataFrame:
#                  From               To  Distance_km
# 0     PURBI CHAMPARAN            BUXAR   149.692085
# 1     PURBI CHAMPARAN           ARARIA   249.018804
# 2     PURBI CHAMPARAN  KAIMUR (BHABUA)   220.660820
# 3     PURBI CHAMPARAN        MADHUBANI   135.671846
# 4     PURBI CHAMPARAN      MUZAFFARPUR    69.464193
# ...               ...              ...          ...
# 1401          SHEOHAR        MADHEPURA   184.253281
# 1402          SHEOHAR         KHAGARIA   180.777352
# 1403          SHEOHAR          KATIHAR   259.203501
# 1404          SHEOHAR        JEHANABAD   150.866517
# 1405          SHEOHAR           ROHTAS   213.132313
#
# [1406 rows x 3 columns]

# %%
df_coordinates.to_csv('C:/Users/kshit/Downloads/df_coordinates.csv',index = False)

# %%
bihar_cold_storage.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237 entries, 0 to 236
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   District        237 non-null    object
#  1   Name & Address  237 non-null    object
#  2   Capacity        237 non-null    int64
#  3   Sector          237 non-null    object
#  4   Commodity       237 non-null    object
#  5   Remarks         16 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 11.2+ KB

# %%
bihar_cold_storage.head()
# Out:
#      District                                     Name & Address  Capacity  \
# 0      ARARIA    BISCOMAUN1 Cold Storage, Agrl. Yard, Forbesganj      4000
# 1      ARARIA             Ganga Cold Storage (P) Ltd., Bathunaha      5850
# 2      ARARIA        Sima Cold Storage & Ice Factory, Forbesganj      1700
# 3  AURANGABAD  Shankar Cold Storage And Ice Factory, Ramchand...      1400
# 4   BEGUSARAI    Anupam Cold Storage (P) Ltd., Phulwari, Barauni      5000
#
#    Sector     Commodity Remarks
# 0  Co-op.        Potato     NaN
# 1    Pvt.        Potato     NaN
# 2    Pvt.        Potato     NaN
# 3    Pvt.        Potato     NaN
# 4    Pvt.  Multipurpose     NaN

# %%
biharpotatodata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   District               38 non-null     object
#  1   Year                   38 non-null     object
#  2   Area (Hectare)         38 non-null     int64
#  3   Production (Tonnes)    38 non-null     object
#  4   Yield (Tonne/Hectare)  38 non-null     float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 1.6+ KB

# %%
biharpotatodata['Production (Tonnes)'] = pd.to_numeric(biharpotatodata['Production (Tonnes)'], errors='coerce')

# %%
biharpotatodata['Year'] = pd.to_numeric(biharpotatodata['Year'], errors='coerce')

# %%
biharpotatodata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   District               38 non-null     object
#  1   Year                   0 non-null      float64
#  2   Area (Hectare)         38 non-null     int64
#  3   Production (Tonnes)    36 non-null     float64
#  4   Yield (Tonne/Hectare)  38 non-null     float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 1.6+ KB

# %%
biharpotatodata.head(38)
# Out:
#               District  Year  Area (Hectare)  Production (Tonnes)  \
# 0               ARARIA   NaN            1327              27405.0
# 1                ARWAL   NaN             655              13850.0
# 2           AURANGABAD   NaN             686              14505.0
# 3                BANKA   NaN             833              14905.0
# 4            BEGUSARAI   NaN            4613              57363.0
# 5            BHAGALPUR   NaN             366               6549.0
# 6              BHOJPUR   NaN            3101              65772.0
# 7                BUXAR   NaN             949              20128.0
# 8            DARBHANGA   NaN            1803              33256.0
# 9                 GAYA   NaN            2623              55463.0
# 10           GOPALGANJ   NaN            2481              28852.0
# 11               JAMUI   NaN            1068              13281.0
# 12           JEHANABAD   NaN             248               5244.0
# ...

# %%
biharpotatodata['Production (Tonnes)'] = biharpotatodata['Production (Tonnes)'].fillna(
    biharpotatodata['Area (Hectare)'] * biharpotatodata['Yield (Tonne/Hectare)']
)

# %%
potatoprodn_heatmap = biharpotatodata.set_index('District')

# Plot the heatmap for 'Yield (Tonne/Hectare)'
plt.figure(figsize=(10, 6))
sns.heatmap(potatoprodn_heatmap[['Yield (Tonne/Hectare)']], annot=True, cmap='YlGnBu', fmt=".2f")
plt.title("Yield (Tonne/Hectare) by District")
plt.show()

# %%
sufficiency_results = []

for idx, row in biharpotatodata.iterrows():
    district = row['District']
    production = row['Production (Tonnes)']
    required_storage = row['Production (Tonnes)']
    
    # Calculate total storage capacity for the district in bihar_cold_storage
    total_capacity = bihar_cold_storage.loc[bihar_cold_storage['District'] == district, 'Capacity'].sum()
    
    # Determine if storage is sufficient
    is_sufficient = total_capacity >= required_storage
    if is_sufficient:
        extra_storage_space = total_capacity - required_storage
        more_space_needed = 0
    else:
        extra_storage_space = 0
        more_space_needed = required_storage - total_capacity

    # Store result
    sufficiency_results.append({
        'District': district,
        'Production': production,
        'Required Storage for Potatoes': required_storage,
        'Total Cold Storage Capacity': total_capacity,
        'Is Sufficient': is_sufficient,
        'Extra Storage Space': extra_storage_space,
        'More Space Required': more_space_needed
    })

# Convert results to DataFrame
sufficiency_df = pd.DataFrame(sufficiency_results)

# Display the result
print(sufficiency_df)
# Out:
#               District  Production  Required Storage for Potatoes  \
# 0               ARARIA    27405.00                       27405.00
# 1                ARWAL    13850.00                       13850.00
# 2           AURANGABAD    14505.00                       14505.00
# 3                BANKA    14905.00                       14905.00
# 4            BEGUSARAI    57363.00                       57363.00
# 5            BHAGALPUR     6549.00                        6549.00
# 6              BHOJPUR    65772.00                       65772.00
# 7                BUXAR    20128.00                       20128.00
# 8            DARBHANGA    33256.00                       33256.00
# 9                 GAYA    55463.00                       55463.00
# 10           GOPALGANJ    28852.00                       28852.00
# 11               JAMUI    13281.00                       13281.00
# 12           JEHANABAD     5244.00                        5244.00
# ...

# %%
sufficiency_df['Is Sufficient'].value_counts()
# Out:
# Is Sufficient
# False    22
# True     16
# Name: count, dtype: int64

# %%
sufficiency_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   District                       38 non-null     object
#  1   Production                     38 non-null     float64
#  2   Required Storage for Potatoes  38 non-null     float64
#  3   Total Cold Storage Capacity    38 non-null     int64
#  4   Is Sufficient                  38 non-null     bool
#  5   Extra Storage Space            38 non-null     float64
#  6   More Space Required            38 non-null     float64
# dtypes: bool(1), float64(4), int64(1), object(1)
# memory usage: 1.9+ KB

# %%
# Find the index of the maximum value in the 'More Space Required' column
max_index = sufficiency_df['More Space Required'].idxmax()

# Get the 'District' corresponding to the maximum 'More Space Required'
district_with_max_need = sufficiency_df.loc[max_index, 'District']

print("District with the most space needed:", district_with_max_need,'-', sufficiency_df['More Space Required'].max())
# Out:
# District with the most space needed: SAMASTIPUR - 175966.68000000002

# %%
# Find the index of the maximum value in the 'Extra Storage Space' column
max_index_for_extra_space = sufficiency_df['Extra Storage Space'].idxmax()

# Get the 'District' corresponding to the maximum 'Extra Storage Space'
district_with_max_extra_storage = sufficiency_df.loc[max_index_for_extra_space, 'District']

print("District with the most extra space:", district_with_max_extra_storage,'-',sufficiency_df['Extra Storage Space'].max() )
# Out:
# District with the most extra space: PATNA - 42263.0

# %%
surplusspace_df = sufficiency_df[sufficiency_df['Extra Storage Space'] > 0]
shortfallspace_df = sufficiency_df[sufficiency_df['More Space Required'] > 0]

# %%
surplusspace_df
# Out:
#            District  Production  Required Storage for Potatoes  \
# 4         BEGUSARAI     57363.0                        57363.0
# 5         BHAGALPUR      6549.0                         6549.0
# 7             BUXAR     20128.0                        20128.0
# 9              GAYA     55463.0                        55463.0
# 10        GOPALGANJ     28852.0                        28852.0
# 12        JEHANABAD      5244.0                         5244.0
# 13  KAIMUR (BHABUA)      4348.0                         4348.0
# 17       LAKHISARAI      1405.0                         1405.0
# 21      MUZAFFARPUR     40499.0                        40499.0
# 22          NALANDA     98545.0                        98545.0
# 25            PATNA     52382.0                        52382.0
# 26  PURBI CHAMPARAN     62482.0                        62482.0
# 27           PURNIA      8096.0                         8096.0
# 28           ROHTAS     10690.0                        10690.0
# ...

# %%
shortfallspace_df
# Out:
#               District  Production  Required Storage for Potatoes  \
# 0               ARARIA    27405.00                       27405.00
# 1                ARWAL    13850.00                       13850.00
# 2           AURANGABAD    14505.00                       14505.00
# 3                BANKA    14905.00                       14905.00
# 6              BHOJPUR    65772.00                       65772.00
# 8            DARBHANGA    33256.00                       33256.00
# 11               JAMUI    13281.00                       13281.00
# 14             KATIHAR    46942.00                       46942.00
# 15            KHAGARIA     8356.00                        8356.00
# 16          KISHANGANJ    23708.00                       23708.00
# 18           MADHEPURA    46901.00                       46901.00
# 19           MADHUBANI    35986.00                       35986.00
# 20              MUNGER     4066.00                        4066.00
# ...

# %%
potato_pricedata = pd.read_excel("C:/Users/kshit/Downloads/potatopricedata.xlsx")

# %%
potato_pricedata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 2 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   District                   38 non-null     object
#  1   Average Price per Quintal  38 non-null     object
# dtypes: object(2)
# memory usage: 736.0+ bytes

# %%
potato_pricedata.head()
# Out:
#      District Average Price per Quintal
# 0      ARARIA                      2150
# 1       ARWAL             Not available
# 2  AURANGABAD             Not available
# 3       BANKA             Not available
# 4   BEGUSARAI                      1450

# %%
potato_pricedata['Average Price per Quintal'] =  pd.to_numeric(potato_pricedata['Average Price per Quintal'],errors = 'coerce')

# %%
potato_pricedata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 2 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   District                   38 non-null     object
#  1   Average Price per Quintal  33 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 736.0+ bytes

# %%
potato_pricedata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 2 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   District                   38 non-null     object
#  1   Average Price per Quintal  33 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 736.0+ bytes

# %%
potato_pricedata['Average Price per Quintal'] = pd.to_numeric(
    potato_pricedata['Average Price per Quintal'], errors='coerce').fillna(0)

# %%
sufficiency_df['District'].unique()
# Out:
# array(['ARARIA', 'ARWAL', 'AURANGABAD', 'BANKA', 'BEGUSARAI', 'BHAGALPUR',
#        'BHOJPUR', 'BUXAR', 'DARBHANGA', 'GAYA', 'GOPALGANJ', 'JAMUI',
#        'JEHANABAD', 'KAIMUR (BHABUA)', 'KATIHAR', 'KHAGARIA',
#        'KISHANGANJ', 'LAKHISARAI', 'MADHEPURA', 'MADHUBANI', 'MUNGER',
#        'MUZAFFARPUR', 'NALANDA', 'NAWADA', 'PASHCHIM CHAMPARAN', 'PATNA',
#        'PURBI CHAMPARAN', 'PURNIA', 'ROHTAS', 'SAHARSA', 'SAMASTIPUR',
#        'SARAN', 'SHEIKHPURA', 'SHEOHAR', 'SITAMARHI', 'SIWAN', 'SUPAUL',
#        'VAISHALI'], dtype=object)

# %%
potato_pricedata['District'].unique()
# Out:
# array(['ARARIA', 'ARWAL', 'AURANGABAD', 'BANKA', 'BEGUSARAI', 'BHAGALPUR',
#        'BHOJPUR', 'BUXAR', 'DARBHANGA', 'GAYA', 'GOPALGANJ', 'JAMUI',
#        'JEHANABAD', 'KAIMUR (BHABUA)', 'KATIHAR', 'KHAGARIA',
#        'KISHANGANJ', 'LAKHISARAI', 'MADHEPURA', 'MADHUBANI', 'MUNGER',
#        'MUZAFFARPUR', 'NALANDA', 'NAWADA', 'PASHCHIM CHAMPARAN', 'PATNA',
#        'PURBI CHAMPARAN', 'PURNIA', 'ROHTAS', 'SAHARSA', 'SAMASTIPUR',
#        'SARAN', 'SHEIKHPURA', 'SHEOHAR', 'SITAMARHI', 'SIWAN', 'SUPAUL',
#        'VAISHALI'], dtype=object)

# %%
df_distances['From'].unique()
# Out:
# array(['MADHEPURA', 'GOPALGANJ', 'BANKA', 'SHEOHAR', 'ROHTAS',
#        'MUZAFFARPUR', 'NAWADA', 'GAYA', 'SAMASTIPUR', 'LAKHISARAI',
#        'ARWAL', 'SIWAN', 'PURNIA', 'KAIMUR (BHABUA)', 'BHAGALPUR',
#        'PASHCHIM CHAMPARAN', 'BEGUSARAI', 'PURBI CHAMPARAN', 'KATIHAR',
#        'BHOJPUR', 'JEHANABAD', 'SARAN', 'JAMUI', 'ARARIA', 'SAHARSA',
#        'VAISHALI', 'PATNA', 'BUXAR', 'KHAGARIA', 'SHEIKHPURA', 'NALANDA',
#        'SUPAUL', 'DARBHANGA', 'SITAMARHI', 'AURANGABAD', 'MADHUBANI',
#        'KISHANGANJ', 'MUNGER'], dtype=object)

# %%
seta = set(df_distances['From'].unique())
setb = set(sufficiency_df['District'].unique())

# %%
setb.difference(seta)
# Out:
# set()

# %%
setb.intersection(seta)
# Out:
# {'ARARIA',
#  'ARWAL',
#  'AURANGABAD',
#  'BANKA',
#  'BEGUSARAI',
#  'BHAGALPUR',
#  'BHOJPUR',
#  'BUXAR',
#  'DARBHANGA',
#  'GAYA',
#  'GOPALGANJ',
#  'JAMUI',
#  'JEHANABAD',
#  'KAIMUR (BHABUA)',
#  'KATIHAR',
#  'KHAGARIA',
#  'KISHANGANJ',
#  'LAKHISARAI',
#  'MADHEPURA',
#  'MADHUBANI',
#  'MUNGER',
#  'MUZAFFARPUR',
#  'NALANDA',
#  'NAWADA',
#  'PASHCHIM CHAMPARAN',
#  'PATNA',
#  'PURBI CHAMPARAN',
#  'PURNIA',
#  'ROHTAS',
#  'SAHARSA',
#  'SAMASTIPUR',
#  'SARAN',
#  'SHEIKHPURA',
#  'SHEOHAR',
#  'SITAMARHI',
#  'SIWAN',
#  'SUPAUL',
#  'VAISHALI'}

# %%
shortfallspace_df['District'].unique()
# Out:
# array(['ARARIA', 'ARWAL', 'AURANGABAD', 'BANKA', 'BHOJPUR', 'DARBHANGA',
#        'JAMUI', 'KATIHAR', 'KHAGARIA', 'KISHANGANJ', 'MADHEPURA',
#        'MADHUBANI', 'MUNGER', 'NAWADA', 'PASHCHIM CHAMPARAN', 'SAHARSA',
#        'SAMASTIPUR', 'SHEIKHPURA', 'SHEOHAR', 'SITAMARHI', 'SIWAN',
#        'SUPAUL'], dtype=object)

# %%
potato_pricedata.head(38)
# Out:
#               District  Average Price per Quintal
# 0               ARARIA                     2150.0
# 1                ARWAL                        0.0
# 2           AURANGABAD                        0.0
# 3                BANKA                        0.0
# 4            BEGUSARAI                     1450.0
# 5            BHAGALPUR                     2575.0
# 6              BHOJPUR                     2500.0
# 7                BUXAR                     2500.0
# 8            DARBHANGA                     1300.0
# 9                 GAYA                     3105.0
# 10           GOPALGANJ                     1380.0
# 11               JAMUI                     2400.0
# 12           JEHANABAD                     2550.0
# 13     KAIMUR (BHABUA)                     2000.0
# 14             KATIHAR                     2200.0
# 15            KHAGARIA                     1150.0
# 16          KISHANGANJ                     2500.0
# 17          LAKHISARAI                     1495.0
# ...

# %%
shortfallspace_df
# Out:
#               District  Production  Required Storage for Potatoes  \
# 0               ARARIA    27405.00                       27405.00
# 1                ARWAL    13850.00                       13850.00
# 2           AURANGABAD    14505.00                       14505.00
# 3                BANKA    14905.00                       14905.00
# 6              BHOJPUR    65772.00                       65772.00
# 8            DARBHANGA    33256.00                       33256.00
# 11               JAMUI    13281.00                       13281.00
# 14             KATIHAR    46942.00                       46942.00
# 15            KHAGARIA     8356.00                        8356.00
# 16          KISHANGANJ    23708.00                       23708.00
# 18           MADHEPURA    46901.00                       46901.00
# 19           MADHUBANI    35986.00                       35986.00
# 20              MUNGER     4066.00                        4066.00
# ...

# %%
price_2023 = pd.read_csv("C:/Users/kshit/Downloads/2023.csv")
price_2022 =  pd.read_csv("C:/Users/kshit/Downloads/2022.csv")
price_2024 =  pd.read_csv("C:/Users/kshit/Downloads/2024.csv")

# %%
price_2022['census_district_name'].unique()
# Out:
# array(['Purba Champaran', 'Bhagalpur', 'Bhojpur', 'Gaya', 'Jamui',
#        'Kaimur (Bhabua)', 'Arwal ', 'Buxar', 'Gopalganj', 'Samastipur',
#        'Nawada', 'Darbhanga', 'Araria', 'Begusarai', 'Patna', 'Nalanda',
#        'Rohtas', 'Siwan', 'Sitamarhi', 'Pashchim Champaran', 'Kishanganj',
#        'Madhubani', 'Sheikhpura', 'Muzaffarpur', 'Madhepura',
#        'Jehanabad ', 'Saharsa', 'Purnia', 'Supaul', 'Aurangabad', 'Saran',
#        'Banka', 'Katihar', 'Vaishali', 'Lakhisarai', 'Munger', 'Khagaria',
#        'Sheohar'], dtype=object)

# %%
price_list = [price_2023,price_2022,price_2024]
for df in price_list:
    df['district'] = df['census_district_name']
    df.drop(['census_district_name'], axis=1, inplace=True)
    bihar_cold_storage['District'] = bihar_cold_storage['District'].replace({'JEHANANBAD':'JEHANABAD'})
    df['district'] =  df['district'].replace({'Purba Champaran':'Purbi Champaran'})
    df['district'] = df['district'].str.upper()

# %%
pricedf_dict = {'price_2022': price_2022, 'price_2023': price_2023, 'price_2024': price_2024}

# Dictionary to store the results
avg_price_results = {}

# Process each DataFrame
for name, df in pricedf_dict.items():
    
    # Convert `date` column to datetime format
    df['date'] = pd.to_datetime(df['date'])
    
    # Extract year and month for grouping
    df['year_month'] = df['date'].dt.to_period('M')
    
    # Group by `district` and `year_month`, then calculate the average `modal_price`
    df_avg_price = df.groupby(['district', 'year_month']).agg(avg_modal_price=('modal_price', 'mean')).reset_index()
    
    # Convert `year_month` back to string format if desired
    df_avg_price['year_month'] = df_avg_price['year_month'].astype(str)
    
    # Store the result in the dictionary with the key as the DataFrame name
    avg_price_results[name] = df_avg_price

# Display the results
for year, df_avg_price in avg_price_results.items():
    print(f"Results for {year}:\n", df_avg_price, "\n")
# Out:
# Results for price_2022:
#       district year_month  avg_modal_price
# 0      ARARIA    2022-02      1017.111111
# 1      ARARIA    2022-03      1032.017544
# 2      ARARIA    2022-04       951.923077
# 3      ARARIA    2022-05       951.200000
# 4      ARARIA    2022-06      1464.193548
# ..        ...        ...              ...
# 391  VAISHALI    2022-08      1572.000000
# 392  VAISHALI    2022-09      1603.982301
# 393  VAISHALI    2022-10      1661.363636
# 394  VAISHALI    2022-11      1679.292929
# 395  VAISHALI    2022-12      1493.670886
#
# [396 rows x 3 columns]
#
# Results for price_2023:
#       district year_month  avg_modal_price
# 0      ARARIA    2023-01      1030.714286
# 1      ARARIA    2023-02       805.625000
# 2      ARARIA    2023-03       850.000000
# 3      ARARIA    2023-08      7977.142857
# 4      ARARIA    2023-09      1131.944444
# ..        ...        ...              ...
# 264  VAISHALI    2023-08     10704.761905
# ...

# %%
import pandas as pd

# Combine all years' average price data into a single DataFrame
all_avg_prices = pd.concat(avg_price_results.values())

# Calculate the overall average `modal_price` for each district across all years
district_avg_price = all_avg_prices.groupby('district')['avg_modal_price'].mean().reset_index()

# Calculate the median average price across all districts (or you could use the overall mean)
overall_median_price = district_avg_price['avg_modal_price'].median()

# Add a column to classify each district as "High-Demand" or "Low-Demand"
district_avg_price['demand_category'] = district_avg_price['avg_modal_price'].apply(
    lambda x: 'High-Demand' if x > overall_median_price else 'Low-Demand'
)

# Display the high-demand and low-demand classification
print(district_avg_price)
district_avg_price.to_excel("C:/Users/kshit/Downloads/potato_pricedata.xlsx", index=False)
# Out:
#               district  avg_modal_price demand_category
# 0               ARARIA      1628.795287      Low-Demand
# 1               ARWAL       1539.335155      Low-Demand
# 2           AURANGABAD      1848.345785     High-Demand
# 3                BANKA      1642.020632      Low-Demand
# 4            BEGUSARAI      1772.411503      Low-Demand
# 5            BHAGALPUR      1696.054400      Low-Demand
# 6              BHOJPUR      2212.429511     High-Demand
# 7                BUXAR      1619.095700      Low-Demand
# 8            DARBHANGA      1196.566644      Low-Demand
# 9                 GAYA      1575.000000      Low-Demand
# 10           GOPALGANJ      1940.797194     High-Demand
# 11               JAMUI      1584.165993      Low-Demand
# 12           JEHANABAD      2600.000000     High-Demand
# 13          JEHANABAD       1951.330782     High-Demand
# 14     KAIMUR (BHABUA)      1245.077431      Low-Demand
# 15             KATIHAR      1765.342103      Low-Demand
# ...

# %%
price_stability_results = {}
price_stability_results[f"{name}_monthly_avg"] = district_avg_price
    
    # Calculate the standard deviation and variance of `modal_price` by district for the entire year
price_volatility = df.groupby('district').agg(
        price_std_dev=('modal_price', 'std'),
        price_variance=('modal_price', 'var')
    ).reset_index()
    
    # Store the volatility results in the dictionary
price_stability_results[f"{name}_volatility"] = price_volatility

# Display the results
for year, df_result in price_stability_results.items():
    print(f"Results for {year}:\n", df_result, "\n")
# Out:
# Results for price_2024_monthly_avg:
#                district  avg_modal_price demand_category
# 0               ARARIA      1628.795287      Low-Demand
# 1               ARWAL       1539.335155      Low-Demand
# 2           AURANGABAD      1848.345785     High-Demand
# 3                BANKA      1642.020632      Low-Demand
# 4            BEGUSARAI      1772.411503      Low-Demand
# 5            BHAGALPUR      1696.054400      Low-Demand
# 6              BHOJPUR      2212.429511     High-Demand
# 7                BUXAR      1619.095700      Low-Demand
# 8            DARBHANGA      1196.566644      Low-Demand
# 9                 GAYA      1575.000000      Low-Demand
# 10           GOPALGANJ      1940.797194     High-Demand
# 11               JAMUI      1584.165993      Low-Demand
# 12           JEHANABAD      2600.000000     High-Demand
# 13          JEHANABAD       1951.330782     High-Demand
# 14     KAIMUR (BHABUA)      1245.077431      Low-Demand
# ...

# %%
# bihar_cold_storage,biharpotatodata,potato_pricedata


# Save each DataFrame as a separate Excel file in the specified directory
bihar_cold_storage.to_excel( 'C:/Users/kshit/Downloads/bihar_cold_storage.xlsx', index=False)
biharpotatodata.to_excel( 'C:/Users/kshit/Downloads/biharpotatodata.xlsx', index=False)
potato_pricedata.to_excel( 'C:/Users/kshit/Downloads/potato_pricedata.xlsx', index=False)

# %%
df_distances.to_excel( 'C:/Users/kshit/Downloads/df_distances.xlsx', index=False)

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# Group by 'District' and sum the 'Capacity'
district_capacity = bihar_cold_storage.groupby('District')['Capacity'].sum().sort_values(ascending=False)

# Plot the bar chart
plt.figure(figsize=(12, 6))
district_capacity.plot(kind='bar', color='skyblue')
plt.title('District-wise Cold Storage Capacity', fontsize=16)
plt.xlabel('District', fontsize=12)
plt.ylabel('Total Capacity', fontsize=12)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.tight_layout()
plt.show()

# %%
district_capacity_df = bihar_cold_storage.groupby('District', as_index=False)['Capacity'].sum().sort_values(by='Capacity', ascending=False)

# Display the new DataFrame
print(district_capacity_df)
# Out:
#               District  Capacity
# 16             NALANDA     99900
# 19               PATNA     94645
# 29            VAISHALI     81743
# 25               SARAN     74975
# 2            BEGUSARAI     66600
# 20     PURBI CHAMPARAN     64305
# 7                 GAYA     56630
# 24          SAMASTIPUR     55400
# 15         MUZAFFARPUR     48940
# 8            GOPALGANJ     34150
# 18  PASHCHIM CHAMPARAN     32462
# 21              PURNIA     31800
# 5                BUXAR     23700
# 3            BHAGALPUR     20600
# 28               SIWAN     16550
# 4              BHOJPUR     16500
# 11             KATIHAR     12200
# 22              ROHTAS     11950
# 0               ARARIA     11550
# 14           MADHUBANI      9300
# 17              NAWADA      6600
# 12            KHAGARIA      6300
# 9            JEHANABAD      6000
# 10     KAIMUR (BHABUA)      5600
# 23             SAHARSA      4000
# 26          SHEIKHPURA      4000
# 27           SITAMARHI      4000
# ...

# %%
cold_storage = pd.read_excel('C:/Users/kshit/Downloads/bihar_cold_storage.xlsx')

# %%
cold_storage.head(10)
# Out:
#      District                                     Name & Address  Capacity  \
# 0      ARARIA    BISCOMAUN1 Cold Storage, Agrl. Yard, Forbesganj      4000
# 1      ARARIA             Ganga Cold Storage (P) Ltd., Bathunaha      5850
# 2      ARARIA        Sima Cold Storage & Ice Factory, Forbesganj      1700
# 3  AURANGABAD  Shankar Cold Storage And Ice Factory, Ramchand...      1400
# 4   BEGUSARAI    Anupam Cold Storage (P) Ltd., Phulwari, Barauni      5000
# 5   BEGUSARAI              Barauni Co-op. Sitagarh Ltd., Barauni      4300
# 6   BEGUSARAI    Begusarai Cold Storage & Ice Factory, Begusarai      1300
# 7   BEGUSARAI          Himganga Cold Storage (P) Ltd., Begusarai      6000
# 8   BEGUSARAI  Kesav Sheet Bhandar (P) Ltd., Ramjanpur, Begus...      6000
# 9   BEGUSARAI               Laxmi Cold Storage, Viwan, Begasarai      5500
#
#    Sector Commodity Remarks
# 0  Co-op.    Potato     NaN
# 1    Pvt.    Potato     NaN
# 2    Pvt.    Potato     NaN
# ...

# %%
cold_storage['Commodity'] = cold_storage['Commodity'].replace('Multipurpose', 'Potato')

# %%
biharpotatodata.head()
# Out:
#      District         Year  Area (Hectare) Production (Tonnes)  \
# 0      ARARIA  2022 - 2023            1327               27405
# 1       ARWAL  2022 - 2023             655               13850
# 2  AURANGABAD  2022 - 2023             686               14505
# 3       BANKA  2022 - 2023             833               14905
# 4   BEGUSARAI  2022 - 2023            4613               57363
#
#    Yield (Tonne/Hectare)
# 0                  20.65
# 1                  21.15
# 2                  21.14
# 3                  17.89
# 4                  12.44
